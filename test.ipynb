# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\anurag.sahu\Desktop\Graphrag\kg_project\data\sample_data.xlsx',sheet_name='Sheet1')

df.head()
# Out:
#     Employee Employee Name Week Start On Time Sheet State  \
# 0        NaN           NaN    2026-01-05    Not Submitted
# 1  1602511.0  A Babu Reddy    2026-01-05    Not Submitted
# 2  1102326.0    A Devendra    2026-01-05         Approved
# 3  1100102.0    A Jayasree    2026-01-05    Not Submitted
# 4  1013334.0   A Madhulika    2026-01-05         Approved
#
#    Total Submitted Hours  Approved Hours  Resource Is Active  \
# 0                    0.0             0.0                True
# 1                    0.0             0.0               False
# 2                   45.0            45.0                True
# 3                    0.0             0.0               False
# 4                   45.0            45.0                True
#
#    SN Timesheet Users Employee Type Grade                 Email  \
# 0                True           NaN   NaN                   NaN
# 1                True           NaN   NaN       babu.a@yash.com
# ...

# %%
df.columns
# Out:
# Index(['Employee', 'Employee Name', 'Week Start On', 'Time Sheet State',
#        'Total Submitted Hours', 'Approved Hours', 'Resource Is Active',
#        'SN Timesheet Users', 'Employee Type', 'Grade', 'Email',
#        'Immediate Reporting Manager', 'Senior Reporting Manager',
#        'Parent Business Group', 'Parent Business Unit', 'Resource Entity'],
#       dtype='str')

# %%
df[df['Time Sheet State']]
